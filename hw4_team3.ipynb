# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from bs4 import BeautifulSoup # Превращалка html в текст.
import re # Регулярные выражения.

import pymorphy2
import pymystem3

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (18,12)

# %%
train = pd.read_csv('train.csv', sep='\t', encoding='utf8', index_col='id');

# %%
train.head()
# Out:
#                                                  name  \
# id
# 0   Заведующий отделом/секцией в магазин YORK (Уру...
# 1               Наладчик станков и манипуляторов с ПУ
# 2                        Разработчик С++ (Криптограф)
# 3                                         Фрезеровщик
# 4                   Мерчендайзер/продавец-консультант
#
#                                           description  target
# id
# 0   <p><strong>В НОВЫЙ МАГАЗИН YORK (хозтовары) пр...       1
# 1   Обязанности:работа на токарных станках с ЧПУ T...       0
# 2   <strong>Требования:</strong> <ul> <li>Опыт про...       0
# 3   <p>Условия:</p> <ul> <li>На работу вахтовым ме...       0
# 4   <p><strong>Компания Палладиум Стандарт - призн...       1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200000 entries, 0 to 199999
# Data columns (total 3 columns):
# name           200000 non-null object
# description    200000 non-null object
# target         200000 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 6.1+ MB

# %%
def preproc(df_init):
    df_preproc = df_init.copy()
    
    df_preproc['name'].replace(r'\([^()]*\)', '', inplace=True, regex=True) #убирает данные в скобках в столбце 'name' там часто мусор                                                                 
    df_preproc['name'].replace(r'[/]', ' ', inplace=True, regex=True) #убираем слеши
    df_preproc['name'].replace(r'\W[-]\W', '-', inplace=True, regex=True) #заменяем кострукцию ' - ' на '-'
    
    df_preproc['description'].replace(r'<li>', ' ', inplace=True, regex=True)
    
    return df_preproc

# %%
df_preproc = train.pipe(preproc)

# %%
# %%time
df_preproc['description'] = df_preproc['description'].map(lambda stt: BeautifulSoup(stt, "html5lib").get_text())
# Out:
# Wall time: 11min 32s

# %%
df_preproc.head(-5)
# Out:
#                                                      name  \
# id
# 0              Заведующий отделом секцией в магазин YORK
# 1                   Наладчик станков и манипуляторов с ПУ
# 2                                        Разработчик С++
# 3                                             Фрезеровщик
# 4                       Мерчендайзер продавец-консультант
# 5                           Мастер по эксплуатации зданий
# 6                                  Торговый представитель
# 7                                  Торговый представитель
# 8                                    Менеджер по продажам
# 9               Менеджер по работе с ключевыми клиентами
# 10                                     Backend Developer
# 11                                       Продавец-кассир
# 12                       Специалист технической поддержки
# 13                                       Продавец-кассир
# 14                         Менеджер по работе с клиентами
# 15                                         Программист 1С
# 16                                     Директор магазина
# 17                                            PR-менеджер
# 18                      Менеджер по продажам оборудования
# 19                                 Администратор-менеджер
# 20                                            PR-менеджер
# 21                            Младший аналитик баз данных
# 22                                       Продавец-кассир
# 23                  Торговый представитель в Севастополе
# 24                                       Продавец-кассир
# 25           Системный аналитик Системный архитектор XBRL
# 26                         Менеджер по работе с клиентами
# 27                                   Менеджер по продажам
# 28                                 Специалист по качеству
# 29                           Монтажник слаботочных систем
# ...                                                   ...
# 199965                                     DevOps-инженер
# 199966                           Маркетолог Администратор
# 199967         Менеджер по подбору вторичной недвижимости
# 199968                       L1 Customer Support Engineer
# 199969                         Специалист по тестированию
# 199970                  Специалист по внутреннему аудиту
# 199971                            Старший продавец-кассир
# 199972                                   Продавец-кассир
# 199973                    Заместитель Директора магазина
# 199974                                     Программист 1С
# 199975                                Java Test Developer
# 199976                         Региональный представитель
# 199977                               Менеджер по продажам
# 199978  Офис-менеджер Консультант в салон элитной кухо...
# 199979                      Директор салона мягкой мебели
# 199980                                   Продавец-кассир
# 199981                Начальник автотранспортного участка
# 199982  Менеджер по технической поддержке продаж и упр...
# 199983                                   Агент поддержки
# 199984      Специалист по качеству и пищевой безопасности
# 199985         Торговый представитель медицинских изделий
# 199986                                  Главный технолог
# 199987                             Менеджер отдела продаж
# 199988  Ведущий инженер-конструктор по разработке танк...
# 199989                Менеджер по продаже запасных частей
# 199990                                        Оператор 1C
# 199991                                     Программист 1С
# 199992                     Продавец-консультант в с. Майя
# 199993                             Администратор магазина
# 199994                               Продавец-консультант
#
#                                               description  target
# id
# 0       В НОВЫЙ МАГАЗИН YORK (хозтовары) приглашаем на...       1
# 1       Обязанности:работа на токарных станках с ЧПУ T...       0
# 2       Требования:   Опыт программирования на С++  Зн...       0
# 3       Условия:   На работу вахтовым методом в г. Кал...       0
# 4       Компания Палладиум Стандарт - признанный лидер...       1
# 5       Обязанности:   Обеспечение бесперебойной работ...       0
# 6       НА СТАБИЛЬНОЕ И РАСПРОСТРАНЕННОЕ НАПРАВЛЕНИЯ "...       1
# 7       Обязанности:   Функционал работы торгового пре...       1
# 8       Обязанности:   Продажа садовой, лесопарковой т...       1
# 9       Обязанности:   развитие клиентской базы (крупн...       0
# 10      Сегодня Плэйкот - это 8 лет истории, 110 профе...       0
# 11      Для каждого, кто хочет работать и зарабатывать...       0
# 12      Обязанности: -приём только входящих звонков от...       0
# 13      Для каждого, кто хочет работать и зарабатывать...       0
# 14      Друзья! Сейчас мы находимся в поиске инициатив...       1
# 15      Обязанности:   Программирование в среде 1С (УТ...       0
# 16      Ведущая федеральная розничная сеть магазинов «...       0
# 17      Обязанности:   Написание пресс-релизов, пресс-...       0
# 18      Обязанности:   Проведение переговоров и презен...       1
# 19      Обязанности:   Следить за чистотой в магазине,...       1
# 20      Обязанности:   Обеспечение взаимодействия комп...       0
# 21      Kaspi Bank – это место, где необыкновенные люд...       0
# 22      Для каждого, кто хочет работать и зарабатывать...       0
# 23        Компания ООО "Энергокомплект Крым" является ...       1
# 24      Для каждого, кто хочет работать и зарабатывать...       0
# 25      В Управление платформы и сервисов поддержки де...       0
# 26      Мы ищем человека, который занимает активную жи...       1
# 27      Федеральная мониторинговая компания "ТН-ГРУПП"...       1
# 28      Обязанности:   Контроль качества готовой проду...       0
# 29      Должностные обязанности:   Осуществление инвен...       0
# ...                                                   ...     ...
# 199965  Hello dear applicant! "We make an excellent pr...       0
# 199966  В стоматологическую клинику европейского уровн...       0
# 199967  ТРЕНД - лидер рынка недвижимости в СПб В связи...       1
# 199968  Are you an effective communicator who is well ...       0
# 199969    Обязанности:   Анализ описания функционально...       0
# 199970  Требования: Высшее образование по квалификации...       0
# 199971  Обязанности:   Организация рабочего процесса  ...       1
# 199972  Для каждого, кто хочет работать и зарабатывать...       0
# 199973  Ведущая федеральная розничная сеть магазинов «...       0
# 199974  Компания IBS приглашает в свою команду Програм...       0
# 199975  Project Description: The application consists ...       0
# 199976  Мы производим новинку на рынке альтернативного...       1
# 199977  В Ваши обязанности будет входить:   Поиск и пр...       1
# 199978  Привет.  Компания Кухни завтра открыла ваканси...       1
# 199979  Обязанности:   Контроль всех процессов в салон...       1
# 199980  Для каждого, кто хочет работать и зарабатывать...       0
# 199981  Обязанности: - Осуществляет общее руководство ...       0
# 199982  Ты ищешь работу, которая совместит в себе дина...       1
# 199983  Сегодня Плэйкот - это 8 лет истории, 110 профе...       0
# 199984  Обязанности:   поддержание, развитие и сертифи...       0
# 199985  Обязанности:   Осуществлять продвижение и прод...       1
# 199986  Уважаемые кандидаты! В настоящее время осущест...       0
# 199987  В производственную компанию требуется менеджер...       1
# 199988  Обязанности:   Разработка эскизных и техническ...       0
# 199989  Обязанности:   Подбор запасных частей для нужд...       1
# 199990  Обязанности: - ведение базы данных в 1С Торгов...       1
# 199991  В профессиональную IT команду для работы над и...       0
# 199992  Что нужно энергичным людям? Интересная и высок...       1
# 199993  Обязанности:   Управление персоналом (адаптаци...       1
# 199994  Компании ООО "ТОПО" - специализирующейся на оп...       1
#
# [199995 rows x 3 columns]

# %%
""" 
Вот так делать не нужно, работает в 10 раз медленее.
# %%time #20000 - Wall time: 11min 9s
for i in range (0, 20000):
    bs=BeautifulSoup(df_des['description'][i], "html5lib").get_text()
    df_preproc.loc[[i],'description'] = bs """
# Out:
# ' \nВот так делать не нужно, работает в 10 раз медленее.\n%%time #20000 - Wall time: 11min 9s\nfor i in range (0, 20000):\n    bs=BeautifulSoup(df_des[\'description\'][i], "html5lib").get_text()\n    df_preproc.loc[[i],\'description\'] = bs '

# %%
test = pd.read_csv('test.csv', sep='\t', encoding='utf8', index_col='id')
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 170179 entries, 200000 to 370178
# Data columns (total 2 columns):
# name           170179 non-null object
# description    170179 non-null object
# dtypes: object(2)
# memory usage: 3.9+ MB

# %%
# обработка файла test
df_test = test.pipe(preproc)

# %%
df_test['description'] = df_test['description'].map(lambda stt: BeautifulSoup(stt, "html5lib").get_text())

# %%
def text_to_wordlist(text):
        
    text = re.sub('[^а-яёА-ЯЁ]', ' ', text)
    words = text.lower().split()

    return words

# %%
import nltk.data

# %%
def text_to_sentences(text):
        
    tokenizer = nltk.data.load('punkt/english.pickle')
    raw_sentences = tokenizer.tokenize(text.strip())
    
    sentences = []
    for raw_sentence in raw_sentences:
        if len(raw_sentence) > 0:
            sentences.append(text_to_wordlist(raw_sentence))

    return sentences

# %%
# %%time
sentences = []

for description in df_preproc['description']:
    sentences += text_to_sentences(description)
# Out:
# Wall time: 3min 21s

# %%
# %%time
for description in df_test["description"]:
    sentences += text_to_sentences(description)
# Out:
# Wall time: 8min 51s

# %%
# В конце сбора sentences будет list list'ов (список списков) - как и пример выше.
# (Повторюсь) каждый элемент списка sentences - предложение, но представленное в виде списка слов - потому список

# выведем количество элементов этого массива (оно же - количество предложений во всех текста)
print (len(sentences))
# Out:
# 2304353

# %%
# а так же посмотрим на сам массив
print ('\t Первый элемент массива')
print (sentences[0])
print ()
print ('\t Второй элемент массива')
print (sentences[1])
# Out:
# 	 Первый элемент массива
# ['в', 'новый', 'магазин', 'хозтовары', 'приглашаем', 'на', 'постоянную', 'работу', 'руководителя', 'секции', 'хозтовары']
#
# 	 Второй элемент массива
# ['обязанности', 'организация', 'эффективного', 'и', 'культурного', 'обслуживания', 'покупателей', 'организация', 'приемки', 'сдачи', 'товаров', 'на', 'склад', 'консультация', 'покупателей', 'по', 'вопросам', 'касающимся', 'оказываемых', 'услуг', 'контроль', 'своевременной', 'подачи', 'товаров', 'в', 'торговую', 'секцию', 'проверка', 'качества', 'сроков', 'годности', 'тмц', 'наличие', 'маркировок', 'ценников', 'на', 'товарах', 'организация', 'бесперебойной', 'работы', 'товарной', 'секции', 'и', 'участка', 'склада', 'закрепленного', 'за', 'ней', 'контроль', 'за', 'сохранностью', 'товаров', 'торгового', 'оборудования', 'и', 'прочих', 'материальных', 'ценностей', 'инвентаризация', 'товаров', 'требования', 'знание', 'товарной', 'группы', 'знание', 'правил', 'приемки', 'товара', 'опыт', 'работы', 'в', 'розничной', 'торговле', 'в', 'качестве', 'продавца', 'р']

# %%
# %%time
# симортируем соответствующую функцию из модуля gensim, который должен быть установлен

from gensim.models.word2vec import Word2Vec 

# список параметров, которые можно менять по вашему желанию
num_features = 300  # итоговая размерность вектора каждого слова
min_word_count = 5  # минимальная частотность слова, чтобы оно попало в модель
num_workers = 8     # количество ядер вашего процессора, чтоб запустить обучение в несколько потоков
context = 10        # размер окна 
downsampling = 1e-3 # внутренняя метрика модели

model = Word2Vec(sentences, workers=num_workers, size=num_features,
                 min_count=min_word_count, window=context, sample=downsampling)
# Out:
# Wall time: 1h 24min 53s

# %%
# Финализируем нашу модель. Ее нельзя будет доучить теперь, но она начнет занимать гораздо меньше места
model.init_sims(replace=True)

# %%
model.most_similar(positive=['улица', 'место'], negative=['работа'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('зависит', 0.9436490535736084),
#  ('выше', 0.9310531616210938),
#  ('быстрый', 0.9222092628479004),
#  ('сплоченный', 0.921920895576477),
#  ('стабильный', 0.9217009544372559),
#  ('хороший', 0.9115757346153259),
#  ('неограниченный', 0.9109642505645752),
#  ('ограничений', 0.9101443886756897),
#  ('потолка', 0.9079972505569458),
#  ('средний', 0.9065406322479248)]

# %%
# давайте просмотрим вектор одного из слов
# его длину
print (len(model['улица']))

# и сам вектор
#print (model['улица'])
# Out:
# 300
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Словарь - все слова которые участвуют в модели можно просмотреть так
#model.wv.index2word

# %%
def text_to_vec(words, model, size):
    text_vec = np.zeros((size,), dtype="float32")
    n_words = 0

    index2word_set = set(model.wv.index2word)
    for word in words:
        if word in index2word_set:
            n_words = n_words + 1
            text_vec = np.add(text_vec, model[word])
    
    if n_words != 0:
        text_vec /= n_words
    return text_vec

# %%
def texts_to_vecs(texts, model, size):
    texts_vecs = np.zeros((len(texts), size), dtype="float32")
    
    for i, text in enumerate(texts):
        texts_vecs[i] = text_to_vec(text, model, size)

    return texts_vecs

# %%
# действительно работает, сделаем для всех текстов из train
train_like_word_list = [sum(text_to_sentences(text), []) for text in df_preproc['description']]

# %%
train_vecs = texts_to_vecs(train_like_word_list, model, num_features)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':

# %%
# сделаем тоже самое для test
test_like_word_list = [sum(text_to_sentences(text), []) for text in df_test['description']]

# %%
test_vecs = texts_to_vecs(test_like_word_list, model, num_features)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':

# %%
# Воспользуемся train_vecs, test_vecs, train["sentiment"] 
#    как матрица фичей обучающей выборки, матрица фичей тестовой выборки, таргет для обучающей выборки соответственно

# Стандартный случайный лес в таком случае
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=100, n_jobs=8)
forest = forest.fit(train_vecs, train["target"])
predict = forest.predict(test_vecs)

# И вот задача решена

# %%
predict.shape
# Out:
# (170179,)

# %%
test_out = df_test.drop(['description'], axis=1)
test_out = test_out.drop(['name'], axis=1)
test_out['target'] = predict
test_out.loc[:, 'target'].value_counts()
# Out:
# 0    88836
# 1    81343
# Name: target, dtype: int64

# %%
test_out.to_csv('res_01.csv')

# %%
i=17667
print(df_des['description'][i])
print()
#delscript = re.compile("<script.*?>.+?</script>", re.S)
bs=BeautifulSoup(df_des['description'][i], "html5lib").get_text()
print (bs)
# Out:
# <p>Требуется рабочий на мебельное производство. Необходимы знания и умения работы на присадочном станке!<br />Предлагаем возможность карьерного роста и обучение в процессе работы.</p> <p> </p> <p><strong>Обязанности:</strong></p> <ul> присадка деталей</li> </ul> <p><strong>Требования:</strong></p> <ul> образование не ниже среднего</li> аккуратность</li> исполнительность</li> умение работать в коллективе</li> </ul> <p><strong>Условия:</strong></p> <ul> график 5-2 с 9 до 18 часов</li> оформление по ТК</li> </ul> <ul> Опыт работы от 3 лет</li> </ul>
#
# Требуется рабочий на мебельное производство. Необходимы знания и умения работы на присадочном станке!Предлагаем возможность карьерного роста и обучение в процессе работы.   Обязанности:  присадка деталей  Требования:  образование не ниже среднего аккуратность исполнительность умение работать в коллективе  Условия:  график 5-2 с 9 до 18 часов оформление по ТК   Опыт работы от 3 лет

# %%
def getMeaningfullWords(text):
    words=[]
    tokens=re.findall('[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+', text)
    for t in tokens:
        pv=morph.parse(t)
        for p in pv:
            if p.tag.POS in ['ADJF', 'NOUN', 'VERB']:
                words.append(p.normal_form)
                break
    return words

# %%
def word_vector(df_init):
    df = df_init.copy()
    df['name'].replace(df['name'], [' '.join(getMeaningfullWords(df['name']))], inplace=True, regex=True)
    return df

# %%
df = df_preproc.pipe(word_vector)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-db83ed22d67c> in <module>()
# ----> 1 df = df_preproc.pipe(word_vector)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in pipe(self, func, *args, **kwargs)
#    4255     @Appender(_shared_docs['pipe'] % _shared_doc_kwargs)
#    4256     def pipe(self, func, *args, **kwargs):
# -> 4257         return com._pipe(self, func, *args, **kwargs)
#    4258
#    4259     _shared_docs['aggregate'] = ("""
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\common.py in _pipe(obj, func, *args, **kwargs)
#     630         return func(*args, **kwargs)
#     631     else:
# --> 632         return func(obj, *args, **kwargs)
#
# <ipython-input-40-fb614e5e9685> in word_vector(df_init)
#       1 def word_vector(df_init):
#       2     df = df_init.copy()
# ----> 3     df['name'].replace(df['name'], [' '.join(getMeaningfullWords(df['name']))], inplace=True, regex=True)
#       4     return df
#
# <ipython-input-39-a068c278540b> in getMeaningfullWords(text)
#       1 def getMeaningfullWords(text):
#       2     words=[]
# ----> 3     tokens=re.findall('[А-Яа-яЁё]+\-[А-Яа-яЁё]+|[А-Яа-яЁё]+', text)
#       4     for t in tokens:
#       5         pv=morph.parse(t)
#
# C:\ProgramData\Anaconda3\lib\re.py in findall(pattern, string, flags)
#     220
#     221     Empty matches are included in the result."""
# --> 222     return _compile(pattern, flags).findall(string)
#     223
#     224 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
Прошу помочь с ошибкой при подготовке данных (после очистки тегов)
def tokenized(df_input):
    vectorized = CountVectorizer(ngram_range=(1,2), tokenizer=my_tokenizer)
    #vectorized = TfidfTransformer(norm=None, smooth_idf=False)
    
    vectorized_matrix = vectorized.fit_transform(df_input["texts_without_tags"])
    vectorized_items = vectorized.vocabulary_.items()
    vectorized_matrix = vectorized_matrix.toarray()
    
    df_output = pd.DataFrame(
        vectorized_matrix,
        #np.asarray(vectorized_matrix),
        columns=[x[0] for x in sorted(vectorized_items, key=lambda x: x[1])]
    )
    
    df_output['name'] = df_input['name']
    df_output['sample'] = df_input['sample']
    df_output['target'] = df_input['target']
    
    return df_output;




import pickle
f = open(r'file.txt', 'wb')
obj = Model
pickle.dump(obj, f)
f.close() (edited)
загрузить
obj = pickle.load(f)



У меня падает ядро именно на Random Forest
живёт 2-3 минуты и всё

# %%time
print (‘Обучаем Random Forest...\n’)
from sklearn.ensemble import RandomForestClassifier
# Делаем random forest на 100 деревьев
forest = RandomForestClassifier(n_estimators = 100, n_jobs = -1)
# В версии с 5 000 фич обучение заняло 22 минут 12 секунд, старт в 23-37
forest = forest.fit( train_data_features, train_df[‘target’] )
print (‘Саш, я обучилась!’)
